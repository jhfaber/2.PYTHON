# %%
import pandas as pd

# %%
data = pd.read_csv('sniffer.txt', sep=' ', engine='python',error_bad_lines=False)
# Out:
# Skipping line 345: Expected 15 fields in line 345, saw 17
# Skipping line 403: Expected 15 fields in line 403, saw 17
# Skipping line 436: Expected 15 fields in line 436, saw 19
# Skipping line 485: Expected 15 fields in line 485, saw 19
# Skipping line 775: Expected 15 fields in line 775, saw 17
# Skipping line 860: Expected 15 fields in line 860, saw 17
# Skipping line 861: Expected 15 fields in line 861, saw 17
# Skipping line 863: Expected 15 fields in line 863, saw 17
# Skipping line 901: Expected 15 fields in line 901, saw 19
# Skipping line 947: Expected 15 fields in line 947, saw 19
# Skipping line 972: Expected 15 fields in line 972, saw 19
# Skipping line 1035: Expected 15 fields in line 1035, saw 17
# Skipping line 1074: Expected 15 fields in line 1074, saw 19
# Skipping line 1087: Expected 15 fields in line 1087, saw 17
# Skipping line 1586: Expected 15 fields in line 1586, saw 17
# Skipping line 1644: Expected 15 fields in line 1644, saw 19
# ...

# %%
data
# Out:
#         13:43:36.685119  IP            pffw.6598  >  \
# 0       13:43:36.685661  IP  52.184.180.160.http  >
# 1       13:43:36.685870  IP  52.184.180.160.http  >
# 2       13:43:36.685915  IP  52.184.180.160.http  >
# 3       13:43:36.686119  IP  52.184.180.160.http  >
# 4       13:43:36.686146  IP  52.184.180.160.http  >
# 5       13:43:36.686354  IP  52.184.180.160.http  >
# 6       13:43:36.686384  IP  52.184.180.160.http  >
# 7       13:43:36.686455  IP  192.168.0.165.49630  >
# 8       13:43:36.686583  IP  52.184.180.160.http  >
# 9       13:43:36.686616  IP  52.184.180.160.http  >
# 10      13:43:36.686808  IP  52.184.180.160.http  >
# 11      13:43:36.686849  IP  192.168.0.165.49630  >
# 12      13:43:36.686898  IP  52.184.180.160.http  >
# 13      13:43:36.686954  IP  192.168.0.165.49630  >
# 14      13:43:36.687101  IP  52.184.180.160.http  >
# 15      13:43:36.687132  IP  52.184.180.160.http  >
# 16      13:43:36.687202  IP  192.168.0.165.49630  >
# ...

# %%
data['pffw.6598	'].count()
# Out:
# 13:43:36.685119           105110
# IP                        105080
# pffw.6598                 105080
# >                         105080
# 192.168.0.190.10420:      105079
# Flags                     105076
# [P.],                     105079
# seq                       105048
# 3426322048:3426322256,     57765
# ack                        57764
# 2822022263,                57764
# win                        57753
# 513,                       57753
# length                     37437
# 208                        37437
# dtype: int64
